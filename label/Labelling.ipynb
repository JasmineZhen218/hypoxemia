# %% [markdown]
# ### Read data

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import datetime as dt
from random import sample
import math

# %%
with open('Time-series/spo2_clean.json','r') as f:
    dic=json.load(f)

# %% [markdown]
# ### Labeling creteria
# * Define hypoxemia event: a continuous 5-minute low spo2.
# * Create labels: At least one hypoxemia event occurs in the next 30 minutes, then label **Now** as 1; otherwise, 0

# %%
import label

# %% [markdown]
# ### Example 1

# %%
name=list(dic.keys())[0]
spo2=dic[name]
label.summary(name,spo2)
# Out:
# p000020-2183-04-28-17-47n
# There are 25 positive labels in all
# There are 1189 negative labels in all
# (25, 1189)

# %% [markdown]
# ### Example 2

# %%
name=list(dic.keys())[3]
spo2=dic[name]
label.summary(name,spo2)
# Out:
# p000033-2116-12-25-13-11n
# There are 0 positive labels in all
# There are 22 negative labels in all
# (0, 22)

# %% [markdown]
# ### Example 3

# %%
name=list(dic.keys())[6]
spo2=dic[name]
label.summary(name,spo2)
# Out:
# p000079-2175-09-26-01-25n
# There are 156 positive labels in all
# There are 779 negative labels in all
# (156, 779)

# %% [markdown]
# ### Example 4

# %%
name=list(dic.keys())[9]
spo2=dic[name]
label.summary(name,spo2)
# Out:
# p000109-2141-10-21-02-00n
# There are 0 positive labels in all
# There are 6024 negative labels in all
# (0, 6024)

# %% [markdown]
# ### Example 5

# %%
name=list(dic.keys())[10]
spo2=dic[name]
label.summary(name,spo2)
# Out:
# p000109-2142-01-14-18-53n
# There are 66 positive labels in all
# There are 2721 negative labels in all
# (66, 2721)
